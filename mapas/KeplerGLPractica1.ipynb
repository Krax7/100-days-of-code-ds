# %%
import pandas as pd
import geopandas as gdp
import keplergl

# %% [markdown]
# ## Leer los datos de terremotos

# %%
# read csv
df = pd.read_csv('data/Worldwide-Earthquake-database.csv')
df
# Out:
#         I_D FLAG_TSUNAMI  YEAR  MONTH   DAY  HOUR  MINUTE SECOND  FOCAL_DEPTH  \
# 0         1           No -2150    NaN   NaN   NaN     NaN                 NaN
# 1         2          Yes -2000    NaN   NaN   NaN     NaN    NaN          NaN
# 2         3           No -2000    NaN   NaN   NaN     NaN    NaN         18.0
# 3      5877          Yes -1610    NaN   NaN   NaN     NaN    NaN          NaN
# 4         8           No -1566    NaN   NaN   NaN     NaN                 NaN
# ...     ...          ...   ...    ...   ...   ...     ...    ...          ...
# 6188  10488           No  2020    4.0   1.0  12.0    23.0     27         10.0
# 6189  10490          Yes  2020    5.0   2.0  12.0    51.0      6         17.0
# 6190  10491           No  2020    5.0   7.0  20.0    18.0     22         10.0
# 6191  10494           No  2020    5.0  18.0  13.0    48.0      3         10.0
# 6192  10501          Yes  2020    5.0  29.0   5.0    30.0    NaN          NaN
#
#       EQ_PRIMARY  ...  TOTAL_MISSING  TOTAL_MISSING_DESCRIPTION  \
# 0            7.3  ...            NaN                        NaN
# 1            NaN  ...            NaN                        NaN
# 2            7.1  ...            NaN                        NaN
# 3            NaN  ...            NaN                        NaN
# 4            NaN  ...            NaN                        NaN
# ...          ...  ...            ...                        ...
# 6188         5.3  ...            NaN                        NaN
# 6189         6.6  ...            NaN                        NaN
# 6190         4.6  ...            NaN                        NaN
# 6191         5.2  ...            NaN                        NaN
# 6192         NaN  ...            NaN                        NaN
#
#       TOTAL_INJURIES  TOTAL_INJURIES_DESCRIPTION  \
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2                NaN                         NaN
# 3                NaN                         NaN
# 4                NaN                         NaN
# ...              ...                         ...
# 6188             NaN                         NaN
# 6189             NaN                         NaN
# 6190            22.0                         1.0
# 6191            24.0                         1.0
# 6192             NaN                         NaN
#
#       TOTAL_DAMAGE_MILLIONS_DOLLARS  TOTAL_DAMAGE_DESCRIPTION  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       1.0
# 3                               NaN                       3.0
# 4                               NaN                       NaN
# ...                             ...                       ...
# 6188                          11.28                       3.0
# 6189                            NaN                       NaN
# 6190                            NaN                       NaN
# 6191                            NaN                       2.0
# 6192                            NaN                       NaN
#
#       TOTAL_HOUSES_DESTROYED TOTAL_HOUSES_DESTROYED_DESCRIPTION  \
# 0                        NaN                                NaN
# 1                        NaN                                NaN
# 2                        NaN                                1.0
# 3                        NaN                                NaN
# 4                        NaN                                NaN
# ...                      ...                                ...
# 6188                     NaN                                NaN
# 6189                     NaN                                NaN
# 6190                     NaN                                NaN
# 6191                     NaN                                1.0
# 6192                     NaN                                NaN
#
#      TOTAL_HOUSES_DAMAGED TOTAL_HOUSES_DAMAGED_DESCRIPTION
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3                     NaN                              NaN
# 4                     NaN                              NaN
# ...                   ...                              ...
# 6188                790.0                              3.0
# 6189                  NaN                              NaN
# 6190                  NaN                              NaN
# 6191                  NaN                              NaN
# 6192                  NaN                              NaN
#
# [6193 rows x 47 columns]

# %% [markdown]
# ## Limpieza y preparación de datos

# %%
# lat and lon to numeric, errors converted to nan
df['LONGITUDE'] = pd.to_numeric(df.LONGITUDE, errors='coerce')
df['LATITUDE'] = pd.to_numeric(df.LATITUDE, errors='coerce')

# %%
# drop rows with missing lat, lon and intensity
df.dropna(subset=['LONGITUDE', 'LATITUDE', 'INTENSITY'], inplace=True)

# %%
# convert tsunami flag drom string to int
df['FLAG_TSUNAMI'] = [1 if i=='Yes' else 0 for i in df.FLAG_TSUNAMI.values]

# %%
df
# Out:
#         I_D FLAG_TSUNAMI  YEAR  MONTH   DAY  HOUR  MINUTE SECOND  FOCAL_DEPTH  \
# 1         2          Yes -2000    NaN   NaN   NaN     NaN    NaN          NaN
# 2         3           No -2000    NaN   NaN   NaN     NaN    NaN         18.0
# 4         8           No -1566    NaN   NaN   NaN     NaN                 NaN
# 5        11           No -1450    NaN   NaN   NaN     NaN    NaN          NaN
# 9        14           No  -759    NaN   NaN   NaN     NaN                 NaN
# ...     ...          ...   ...    ...   ...   ...     ...    ...          ...
# 6184  10483           No  2020    3.0  10.0  10.0    18.0      6         23.0
# 6185  10485           No  2020    3.0  18.0  13.0     9.0     31         12.0
# 6186  10486           No  2020    3.0  22.0   5.0    24.0      3         10.0
# 6187  10487          Yes  2020    3.0  25.0   2.0    49.0     21         57.0
# 6189  10490          Yes  2020    5.0   2.0  12.0    51.0      6         17.0
#
#       EQ_PRIMARY  ...  TOTAL_MISSING  TOTAL_MISSING_DESCRIPTION  \
# 1            NaN  ...            NaN                        NaN
# 2            7.1  ...            NaN                        NaN
# 4            NaN  ...            NaN                        NaN
# 5            NaN  ...            NaN                        NaN
# 9            NaN  ...            NaN                        NaN
# ...          ...  ...            ...                        ...
# 6184         5.0  ...            NaN                        NaN
# 6185         5.7  ...            NaN                        NaN
# 6186         5.4  ...            NaN                        NaN
# 6187         7.5  ...            NaN                        NaN
# 6189         6.6  ...            NaN                        NaN
#
#       TOTAL_INJURIES  TOTAL_INJURIES_DESCRIPTION  \
# 1                NaN                         NaN
# 2                NaN                         NaN
# 4                NaN                         NaN
# 5                NaN                         NaN
# 9                NaN                         NaN
# ...              ...                         ...
# 6184             4.0                         1.0
# 6185             NaN                         NaN
# 6186            27.0                         1.0
# 6187             NaN                         NaN
# 6189             NaN                         NaN
#
#       TOTAL_DAMAGE_MILLIONS_DOLLARS  TOTAL_DAMAGE_DESCRIPTION  \
# 1                               NaN                       NaN
# 2                               NaN                       1.0
# 4                               NaN                       NaN
# 5                               NaN                       NaN
# 9                               NaN                       NaN
# ...                             ...                       ...
# 6184                            NaN                       2.0
# 6185                           48.5                       4.0
# 6186                         6000.0                       4.0
# 6187                            NaN                       NaN
# 6189                            NaN                       NaN
#
#       TOTAL_HOUSES_DESTROYED TOTAL_HOUSES_DESTROYED_DESCRIPTION  \
# 1                        NaN                                NaN
# 2                        NaN                                1.0
# 4                        NaN                                NaN
# 5                        NaN                                NaN
# 9                        NaN                                NaN
# ...                      ...                                ...
# 6184                     NaN                                NaN
# 6185                     NaN                                NaN
# 6186                  6305.0                                4.0
# 6187                     NaN                                NaN
# 6189                     NaN                                NaN
#
#      TOTAL_HOUSES_DAMAGED TOTAL_HOUSES_DAMAGED_DESCRIPTION
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 4                     NaN                              NaN
# 5                     NaN                              NaN
# 9                     NaN                              NaN
# ...                   ...                              ...
# 6184               1137.0                              4.0
# 6185                  NaN                              3.0
# 6186              20000.0                              4.0
# 6187                  NaN                              NaN
# 6189                  NaN                              NaN
#
# [2810 rows x 47 columns]

# %% [markdown]
# ## Generamos un mapa y le agregamos datos

# %% [markdown]
# On the menu we have:
# Layers — Defines how the variables are encoded to the map
# Filters — For selecting smaller sets of data
# Interactions — Defines interactions such as Tooltips, search boxes, and others
# Basemap — Defines the style of the world map and other elements like labels, roads, styles

# %%
kepler_map = keplergl.KeplerGl(height=400)
kepler_map
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl()

# %%
kepler_map.add_data(data=df, name="earthquakes")
